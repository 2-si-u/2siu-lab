# %% [markdown]
# # 데이터 전처리
# - 데이터를 분석하기 좋은 형태로 가공하는 과정이다.
# - 원본 데이터를 그대로 사용하는 것이 아니라
#     이상치, 중복데이터, 결속치 등을 처리해서 신뢰할 수 았는 데이터로 만드는 고정을 의미한다.

# %% [markdown]
# ##  이상치(outlier)
# - 관속하거나 수집한 데이터의 범위(군집)에서 많이 벗어나있는 아주작은 값 또는 큰 값을 의미한다.
# - 이상치는 제거하거나 대체하거나 또는 가만히 놔두어도 상관없는지를 판단하여 전처리를 진행해야한다.

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRuY-LwTufVlKJ-r54472gZtIxK7CuP0Ei6gVwSRUy8zWdl1koZIG6VzpR6&s=10" />

# %% [markdown]
# ## 예측
# - 숫자로 알기 힘든 값들을 표현하기위해 기술통계랑을 확인하는 것을 의미한다.
# - min(최소), max(최대), median(최빈), mean(평균)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# 윈도우 맑은 고딕 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
height_list = [181, 280, 158, 110, 170, 160, 155, 146]
avg_height = sum(height_list) / len(height_list)

print(f"평균 키:{avg_height}cm")
print(f"최소 키:{min(height_list)}cm")
print(f"최대 키: {max(height_list)}cm")
# Out:
# 평균 키:170.0cm
# 최소 키:110cm
# 최대 키: 280cm

# %%
plt.figure(figsize=(8, 4))

# 박스플롯 이상치 탐지
plt.boxplot(height_list)
plt.show()

# %% [markdown]
# ## 박스 플롯
# - 이상치 탐색을위해 사용되는 시각화 차트이다
# - 분위수를 기준으로 그려지고 상자안에 그러져 있는 직선이 중위수(Median)을 나타낸다 meaian의 값의 위치에 따라 값들의 분포를 확인할 수 있따
# - 상자의 밑변은 1분위수이고, 윗변은 3분위수를 의미한다
# - 상자의 중심으로 위 아래에 직선이 있는 것을 볼 수 있는데 이것을 울타리라고 부른다.
#
# ## 이상치 계산공식
# - 아래 이상치 공식 Q1 - (1.5 * IQR)     - > Q1: 25% 하위 일분위
# - 위 이상치 공식 Q3 + (1.5 * IQR)        -> Q3: 75% 상위 삼분위
#
# <img style="width:500px;" src="https://blog.kakaocdn.net/dna/dLPevN/btq1caAZMWD/AAAAAAAAAAAAAAAAAAAAACdUyXIwIBA0UI-lNOxgEND-ivrCO7oAkDQNWYlbYDTf/img.png?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1790780399&allow_ip=&allow_referer=&signature=o4DIu2hQNUV89WOVQAkr5VNdrvg%3D" />

# %%
height_list = [181, 158, 170, 160, 155, 146]
avg_height = sum(height_list) / len(height_list)

print(f"평균 키:{avg_height}cm")
print(f"최소 키:{min(height_list)}cm")
print(f"최대 키: {max(height_list)}cm")
# Out:
# 평균 키:161.66666666666666cm
# 최소 키:146cm
# 최대 키: 181cm

# %%
plt.figure(figsize=(8, 4))

# 박스플롯 이상치 탐지
plt.boxplot(height_list)
plt.show()

# %% [markdown]
# ## 이상치 (outlier) 처리방법
# 1. 값을 그대로 냅둔다.
# 2. 값을 제거 하는 방법 (신뢰도 저하, 데이터 버려지는 단점이 있다 -> 값을 많이 제거해버려서 일반화가 됨)
#
# ## 결측치 (outlier) 처리방법
# - 데이터 수집 또는 데이터 셋에서 NULL, NaN 값이 들어가 비어있는 상태를 의미한다
# - 데이터를 수집하는 과정에서 오류, 누락, 값을 저장하는 과정해서 소실한 것을 의미하여 분석전에 반드시 처리해야한다
# - 대체한다면 평균값 최빈값 중앙값 같은 통계수치나 머신러닝의 에측 값 중 적절한 데이터의 특성을 고려하여 대체 해야한다
#
# ![](https://drive.google.com/thumbnail?id=1Xu3g-0MJOJxcXr330-JecGN_nI7Yqoos&sz=w1000)

# %%
df = pd.DataFrame({
    "이름": ["시츄", "하아", "승연", "지성", "혜지", "승기", "우연", "소민"],
    "소득": [1000000, 5500, None, None, 100000, 50000, 3000, 50000]
})

df
# Out:
#    이름         소득
# 0  시츄  1000000.0
# 1  하아     5500.0
# 2  승연        NaN
# 3  지성        NaN
# 4  혜지   100000.0
# 5  승기    50000.0
# 6  우연     3000.0
# 7  소민    50000.0

# %%
df.isna().sum()
# Out:
# 이름    0
# 소득    2
# dtype: int64

# %%
# 결측치 삭제
df.dropna()
# Out:
#    이름         소득
# 0  시츄  1000000.0
# 1  하아     5500.0
# 4  혜지   100000.0
# 5  승기    50000.0
# 6  우연     3000.0
# 7  소민    50000.0

# %%
# 평균 구하기

# %% [markdown]
# ## 최빈값: mode()

# %%
df.fillna(df["소득"].mode()[0])
# Out:
#    이름         소득
# 0  시츄  1000000.0
# 1  하아     5500.0
# 2  승연    50000.0
# 3  지성    50000.0
# 4  혜지   100000.0
# 5  승기    50000.0
# 6  우연     3000.0
# 7  소민    50000.0

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df2["소득"])

plt.show()
# Out:
# ------------------------------------------------------------------------
# KeyError                               Traceback (most recent call last)
# File C:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '소득'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                               Traceback (most recent call last)
# Cell In[62], line 2
#       1 plt.figure(figsize=(6,4))
# ----> 2 plt.boxplot(df2["소득"])
#       4 plt.show()
#
# File C:\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File C:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '소득'

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df.dropna()["소득"])

plt.show()

# %% [markdown]
# ## 중간값: .median()

# %%
df["소득"].median()

# %%
df.fillna(df["소득"].median())

# %% [markdown]
# ## 중복 데이터
# - 동일한 데이터가 여러번 저장된 상태를 의미
# - 중복 데이터가 많아지면 통꼐결과와 왜곡된 분석결과 및 신뢰도가 떨어질 수 있습니다.
# <img src="https://drive.google.com/thumbnail?id=1OyllE-RqUt-47NRgJ0N2oyXHKrvic3db&sz=w1000" width=1000>

# %%
df = pd.DataFrame({
    "이름": ["지호", "승현", "상아", "우영", "우영", "준승", "예나", "수민", "지호", "상아"],
    "취미": ["코딩", "칵테일", "알바", "코딩", "코딩", "코딩", "코딩", "스트레칭", "코딩", "알바"]
})

df

# %%
df.duplicated().sum()

# %%
df2 = df.drop_duplicates()
df2

# %%
df = pd.DataFrame({
    "학번": [i + 1 for i in range(10)],
    "이름": ["지호", "승현", "상아", "우영", "우영", "준승", "예나", "수민", "지호", "상아"],
    "취미": ["코딩", "칵테일", "알바", "코딩", "코딩", "코딩", "코딩", "스트레칭", "코딩", "알바"]
})

df

# %%
df.duplicated(subset=["이름","취미"])
df

# %%
# 윈도우 맑은 고딕 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
import os

base_path = r"C:\kdt_0900_lsu\data_analysis\resource\dataset"
file_name = r"preprocessing.csv.csv"
file_path = os.path.join(base_path, file_name)

# %%
df1 = pd.read_csv(file_path, encoding="cp949", sep="\t")
df1
# Out:
#     id name    age gender city    salary
# 0    1  김철수   28.0      남   서울    3500.0
# 1    2  이영희   31.0      여   부산    4200.0
# 2    3  박민수   25.0      남   대구    3000.0
# 3    4  최지은   29.0      여   인천    3800.0
# 4    5  정수현   34.0      남   광주    4500.0
# 5    6  한유진   27.0      여   대전    3600.0
# 6    7  오세훈   45.0      남   서울    5500.0
# 7    8  강민지   22.0      여   부산    2800.0
# 8    9  윤성호   38.0      남   울산    4900.0
# 9   10  송지수   26.0      여   서울    3400.0
# 10  11  김도윤   30.0      남   수원    4000.0
# 11  12  이다은    NaN      여   성남    3900.0
# 12  13  장현우   33.0      남   고양       NaN
# 13  14  서지민   24.0      여   서울    3100.0
# 14  15  홍길동   29.0      남   서울    3700.0
# 15  16  홍길동   29.0      남   서울    3700.0
# 16  17  김나영   27.0      여   부산    3600.0
# 17  18  이준혁   41.0      남   대전    5300.0
# 18  19  박서연   23.0      여  NaN    2900.0
# 19  20  최민호  999.0      남   서울    4800.0
# 20  21  유지민   35.0      여   광주    4700.0
# 21  22  정우성   -5.0      남   부산    4100.0
# 22  23  한지민   32.0      여   인천    4400.0
# 23  24  오지훈   28.0      남   대구    3500.0
# 24  25  김예린   26.0      여   울산    3300.0
# 25  26  박도현   37.0      남   서울    5200.0
# 26  27  서유리   21.0      여   수원    2700.0
# 27  28  강동원   42.0      남   고양  999999.0
# 28  29  최수빈   25.0      여   성남    3200.0
# 29  30  이상훈   29.0      남   대전    3600.0

# %%
import os

base_path = r"C:\kdt_0900_lsu\data_analysis\resource\dataset"
file_name = r"preprocessing.csv"

file_path = os.path.join(base_path, file_name)

print(file_path)
print(os.path.exists(file_path))
# Out:
# C:\kdt_0900_lsu\data_analysis\resource\dataset\preprocessing.csv
# True

# %% [markdown]
# ## 1단계: 컬럼 타입 확인
# - 각 컬럼이 수지형인지, 범주형/분류형인지 확인해야한다
# - 그 이유는 대체값 전략이 달라기지 때문이다
#   1. 수치형 데이터: 평균값 또는 중앙값 또는 특정 값으로 대체
#   2. 범주형 데이터: 최빈값, 범주 추기하여 처리

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      30 non-null     int64
#  1   name    30 non-null     object
#  2   age     29 non-null     float64
#  3   gender  30 non-null     object
#  4   city    29 non-null     object
#  5   salary  29 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
# 기술통계랑 
df1.describe()
# Out:
#               id         age         salary
# count  30.000000   29.000000      29.000000
# mean   15.500000   62.413793   38237.896552
# std     8.803408  180.348575  184974.502563
# min     1.000000   -5.000000    2700.000000
# 25%     8.250000   26.000000    3400.000000
# 50%    15.500000   29.000000    3700.000000
# 75%    22.750000   34.000000    4500.000000
# max    30.000000  999.000000  999999.000000

# %% [markdown]
# ## 2단계, 각 컬럼 타입의 계획수립
# - id: int - 분류형
# - name: str- 분류형
# - age: float -> int -수치형
# - gender: str - 분류형
# - city: str - 분류형
# - salary  -수치형

# %% [markdown]
# ## 3단계

# %%
# age, city, salary : 결측치가 있다
df1.isna().sum()
# Out:
# id        0
# name      0
# age       1
# gender    0
# city      1
# salary    1
# dtype: int64

# %%
#age에는 이상치가 있다
plt.boxlot(df1["age"].dropna())
plt.show()
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# Cell In[90], line 2
#       1 #age에는 이상치가 있다
# ----> 2 plt.boxlot(df1["age"].dropna())
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'boxlot'

# %% [markdown]
# ## 4단계, 결측치 내제

# %%
# age, city, salary: 결측치가 있다.
# age: 수치형 
# - 중앙값(median)
age_median = df1["age"].median()
df1["age"] = df1["age"].fillna(age_median)
df1
# Out:
#     id name    age gender city    salary
# 0    1  김철수   28.0      남   서울    3500.0
# 1    2  이영희   31.0      여   부산    4200.0
# 2    3  박민수   25.0      남   대구    3000.0
# 3    4  최지은   29.0      여   인천    3800.0
# 4    5  정수현   34.0      남   광주    4500.0
# 5    6  한유진   27.0      여   대전    3600.0
# 6    7  오세훈   45.0      남   서울    5500.0
# 7    8  강민지   22.0      여   부산    2800.0
# 8    9  윤성호   38.0      남   울산    4900.0
# 9   10  송지수   26.0      여   서울    3400.0
# 10  11  김도윤   30.0      남   수원    4000.0
# 11  12  이다은   29.0      여   성남    3900.0
# 12  13  장현우   33.0      남   고양       NaN
# 13  14  서지민   24.0      여   서울    3100.0
# 14  15  홍길동   29.0      남   서울    3700.0
# 15  16  홍길동   29.0      남   서울    3700.0
# 16  17  김나영   27.0      여   부산    3600.0
# 17  18  이준혁   41.0      남   대전    5300.0
# 18  19  박서연   23.0      여  NaN    2900.0
# 19  20  최민호  999.0      남   서울    4800.0
# 20  21  유지민   35.0      여   광주    4700.0
# 21  22  정우성   -5.0      남   부산    4100.0
# 22  23  한지민   32.0      여   인천    4400.0
# 23  24  오지훈   28.0      남   대구    3500.0
# 24  25  김예린   26.0      여   울산    3300.0
# 25  26  박도현   37.0      남   서울    5200.0
# 26  27  서유리   21.0      여   수원    2700.0
# 27  28  강동원   42.0      남   고양  999999.0
# 28  29  최수빈   25.0      여   성남    3200.0
# 29  30  이상훈   29.0      남   대전    3600.0

# %%
# 분류형 -> 중앙값이 없기에 최빈값이나 새로운 컬럼을 만들어서 넣는 방법이 있음

city_mode = df1["city"].mode()[0]
city_mode
# Out:
# '서울'

# %%
df1["city"] = df1.fillna(city_mode)
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df1["city"] = df1.fillna(city_mode)
#
# File C:\anaconda3\Lib\site-packages\pandas\core\frame.py:4301, in DataFrame.__setitem__(self, key, value)
#    4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
# -> 4301     self._set_item_frame_value(key, value)
#    4302 elif (
#    4303     is_list_like(value)
#    4304     and not self.columns.is_unique
#    4305     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    4306 ):
#    4307     # Column to set is duplicated
#    4308     self._setitem_array([key], value)
#
# File C:\anaconda3\Lib\site-packages\pandas\core\frame.py:4429, in DataFrame._set_item_frame_value(self, key, value)
#    4427 len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4428 if len_cols != len(value.columns):
# -> 4429     raise ValueError("Columns must be same length as key")
#    4431 # align right-hand-side columns if self.columns
#    4432 # is multi-index and self[key] is a sub-frame
#    4433 if isinstance(self.columns, MultiIndex) and isinstance(
#    4434     loc, (slice, Series, np.ndarray, Index)
#    4435 ):
#
# ValueError: Columns must be same length as key

# %%
df1
# Out:
#     id name    age gender city    salary
# 0    1  김철수   28.0      남   서울    3500.0
# 1    2  이영희   31.0      여   부산    4200.0
# 2    3  박민수   25.0      남   대구    3000.0
# 3    4  최지은   29.0      여   인천    3800.0
# 4    5  정수현   34.0      남   광주    4500.0
# 5    6  한유진   27.0      여   대전    3600.0
# 6    7  오세훈   45.0      남   서울    5500.0
# 7    8  강민지   22.0      여   부산    2800.0
# 8    9  윤성호   38.0      남   울산    4900.0
# 9   10  송지수   26.0      여   서울    3400.0
# 10  11  김도윤   30.0      남   수원    4000.0
# 11  12  이다은   29.0      여   성남    3900.0
# 12  13  장현우   33.0      남   고양       NaN
# 13  14  서지민   24.0      여   서울    3100.0
# 14  15  홍길동   29.0      남   서울    3700.0
# 15  16  홍길동   29.0      남   서울    3700.0
# 16  17  김나영   27.0      여   부산    3600.0
# 17  18  이준혁   41.0      남   대전    5300.0
# 18  19  박서연   23.0      여  NaN    2900.0
# 19  20  최민호  999.0      남   서울    4800.0
# 20  21  유지민   35.0      여   광주    4700.0
# 21  22  정우성   -5.0      남   부산    4100.0
# 22  23  한지민   32.0      여   인천    4400.0
# 23  24  오지훈   28.0      남   대구    3500.0
# 24  25  김예린   26.0      여   울산    3300.0
# 25  26  박도현   37.0      남   서울    5200.0
# 26  27  서유리   21.0      여   수원    2700.0
# 27  28  강동원   42.0      남   고양  999999.0
# 28  29  최수빈   25.0      여   성남    3200.0
# 29  30  이상훈   29.0      남   대전    3600.0

# %%
# salary 대체값 찾기

# %% [markdown]
# ## 컬럼의 형변환

# %%
df1["age"] = df1["age"].astype(int)
df1["salary"] = df1["salary"].astype(int)
# Out:
# ------------------------------------------------------------------------
# IntCastingNaNError                     Traceback (most recent call last)
# Cell In[97], line 2
#       1 df1["age"] = df1["age"].astype(int)
# ----> 2 df1["salary"] = df1["salary"].astype(int)
#
# File C:\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File C:\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File C:\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File C:\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File C:\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File C:\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File C:\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# ## 5단계, 이상치 대체 또는 제거

# %%
Q1 = df1["salary"].quantile(0.25)
Q3 = df1["salary"].quantile(0.25)

print(f"1사분위 값: {Q1}")
print(f"3사분위 값: {Q3}")
print(f"{IQR}")
# Out:
# 1사분위 값: 3400.0
# 3사분위 값: 3400.0
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[99], line 6
#       4 print(f"1사분위 값: {Q1}")
#       5 print(f"3사분위 값: {Q3}")
# ----> 6 print(f"{IQR}")
#
# NameError: name 'IQR' is not defined

# %%
min_outlier = Q1 - (IQR * 1.5)
max_outlier = Q3 + (IQR * 1.5)

print(f"max outlier: {max_outlier} 초과")
print(f"min outlier: {min_outlier} 이하")
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 min_outlier = Q1 - (IQR * 1.5)
#       2 max_outlier = Q3 + (IQR * 1.5)
#       4 print(f"max outlier: {max_outlier} 초과")
#
# NameError: name 'IQR' is not defined

# %%
outlier_mask = (df1["salary"] > max_outlier) | (df1["salary"] < min_outlier)
df1["salary"][outlier_mask]

# %%
def find_outlier(df, col_name):
    df_copy = df.copy()
    
    Q1 = df1["salary"].quantile(0.25)
    Q3 = df1["salary"].quantile(0.25)

    IQR = Q3 - Q1

    lower = Q1 - (1.5 * IQR)
    upwer = Q3 - (1.5 * IQR)

    mask = ~((df_copy[col_name] < lower) | (df_copy[col_name] > upwer))
        return df_copy[mask]

# %%
def remove_outlier(df, col_name):
    df_copy = df.copy()
    Q1 = df_copy[col_name].quantile(0.25)
    Q3 = df_copy[col_name].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - (1.5 * IQR)
    upper = Q3 + (1.5 * IQR)

    mask = ~((df_copy[col_name] < lower) | (df_copy[col_name] > upper))
    return df_copy[mask]

# %%
df2 = remove_outlier(df1, "salary")
df3 = remove_outlier(df2, "age")
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df2 = remove_outlier(df1, "salary")
#
# NameError: name 'remove_outlier' is not defined

# %% [markdown]
# # 중복값 삭제

# %%
# df4.duplicated(subset=["name", "age", "gender", "city"])
df5 = df4.drop_duplicates(subset=["name", "age", "gender", "city"]).reset_index(drop=True)
df5
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[105], line 2
#       1 # df4.duplicated(subset=["name", "age", "gender", "city"])
# ----> 2 df5 = df4.drop_duplicates(subset=["name", "age", "gender", "city"]).reset_index(drop=True)
#       3 df5
#
# NameError: name 'df4' is not defined
